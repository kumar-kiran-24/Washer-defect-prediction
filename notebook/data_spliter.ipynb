# %%
import tensorflow as tf

# %%
! pip install tensorflow
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow (from versions: none)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: C:\Users\Edwin\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for tensorflow

# %%
import os
import shutil
import random

source_dir = "data/train_data"
train_dir = "data/train"
val_dir = "data/val"

classes = ["defective", "non-defective"]
split_ratio = 0.8

for cls in classes:
    os.makedirs(os.path.join(train_dir, cls), exist_ok=True)
    os.makedirs(os.path.join(val_dir, cls), exist_ok=True)

    class_path = os.path.join(source_dir, cls)

    # only files, skip folders
    files = [
        f for f in os.listdir(class_path)
        if os.path.isfile(os.path.join(class_path, f))
    ]

    random.shuffle(files)

    split_index = int(len(files) * split_ratio)

    train_files = files[:split_index]
    val_files = files[split_index:]

    for file in train_files:
        shutil.copy(
            os.path.join(class_path, file),
            os.path.join(train_dir, cls, file)
        )

    for file in val_files:
        shutil.copy(
            os.path.join(class_path, file),
            os.path.join(val_dir, cls, file)
        )

print("Dataset split completed!")
# Out:
# Dataset split completed!
